# %%
import numpy as np
import pandas as pd
dict1={
    "name":["rohan","seema","mahesh","shruti"],
    "marks":[9,55,67,98],
    "city":["Delhi","Jaipur","Rampur","Barilly"]
}
df=pd.DataFrame(dict1)
df
# Out:
#      name  marks     city
# 0   rohan      9    Delhi
# 1   seema     55   Jaipur
# 2  mahesh     67   Rampur
# 3  shruti     98  Barilly

# %%
df.index=[1,2,3,4]
df
# Out:
#      name  marks     city
# 1   rohan      9    Delhi
# 2   seema     55   Jaipur
# 3  mahesh     67   Rampur
# 4  shruti     98  Barilly

# %%
ser=pd.Series(np.random.rand(20))
ser
# Out:
# 0     0.615157
# 1     0.042505
# 2     0.387695
# 3     0.261889
# 4     0.895663
# 5     0.896076
# 6     0.375711
# 7     0.672627
# 8     0.404727
# 9     0.980743
# 10    0.724318
# 11    0.885821
# 12    0.752246
# 13    0.478978
# 14    0.819606
# 15    0.271310
# 16    0.877397
# 17    0.643642
# 18    0.559044
# 19    0.989836
# dtype: float64

# %%
type(ser)
# Out:
# pandas.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))
newdf
# Out:
#             0         1         2         3         4
# 0    0.664506  0.900184  0.172634  0.810548  0.519839
# 1    0.665756  0.120406  0.570151  0.141388  0.416672
# 2    0.135102  0.371230  0.447675  0.480457  0.215055
# 3    0.508799  0.887753  0.647635  0.961038  0.538663
# 4    0.996207  0.523861  0.336768  0.343678  0.947715
# ..        ...       ...       ...       ...       ...
# 329  0.145783  0.136134  0.833426  0.529654  0.339110
# 330  0.355191  0.934701  0.810297  0.235893  0.818414
# 331  0.205796  0.566691  0.239438  0.774385  0.006662
# 332  0.911662  0.743533  0.881924  0.784352  0.709072
# 333  0.854310  0.275455  0.742860  0.850526  0.569475
#
# [334 rows x 5 columns]

# %%
newdf.head(3)
# Out:
#           0         1         2         3         4
# 0  0.664506  0.900184  0.172634  0.810548  0.519839
# 1  0.665756  0.120406  0.570151  0.141388  0.416672
# 2  0.135102  0.371230  0.447675  0.480457  0.215055

# %%
newdf.tail(3)
# Out:
#             0         1         2         3         4
# 331  0.205796  0.566691  0.239438  0.774385  0.006662
# 332  0.911662  0.743533  0.881924  0.784352  0.709072
# 333  0.854310  0.275455  0.742860  0.850526  0.569475

# %%
newdf.sort_index(axis=0)
# Out:
#             0         1         2         3         4
# 0    0.664506  0.900184  0.172634  0.810548  0.519839
# 1    0.665756  0.120406  0.570151  0.141388  0.416672
# 2    0.135102  0.371230  0.447675  0.480457  0.215055
# 3    0.508799  0.887753  0.647635  0.961038  0.538663
# 4    0.996207  0.523861  0.336768  0.343678  0.947715
# ..        ...       ...       ...       ...       ...
# 329  0.145783  0.136134  0.833426  0.529654  0.339110
# 330  0.355191  0.934701  0.810297  0.235893  0.818414
# 331  0.205796  0.566691  0.239438  0.774385  0.006662
# 332  0.911662  0.743533  0.881924  0.784352  0.709072
# 333  0.854310  0.275455  0.742860  0.850526  0.569475
#
# [334 rows x 5 columns]

# %%
newdf.drop(0,axis=1)
# Out:
#             1         2         3         4
# 0    0.900184  0.172634  0.810548  0.519839
# 1    0.120406  0.570151  0.141388  0.416672
# 2    0.371230  0.447675  0.480457  0.215055
# 3    0.887753  0.647635  0.961038  0.538663
# 4    0.523861  0.336768  0.343678  0.947715
# ..        ...       ...       ...       ...
# 329  0.136134  0.833426  0.529654  0.339110
# 330  0.934701  0.810297  0.235893  0.818414
# 331  0.566691  0.239438  0.774385  0.006662
# 332  0.743533  0.881924  0.784352  0.709072
# 333  0.275455  0.742860  0.850526  0.569475
#
# [334 rows x 4 columns]

# %%
newdf.dropna(inplace=True)
