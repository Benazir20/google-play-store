# %%
import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime
import pytz
import numpy as np

# ------------------------------
# Time Restriction (1PM–2PM IST)
# ------------------------------
ist = pytz.timezone("Asia/Kolkata")
current_time = datetime.now(ist)

if 13 <= current_time.hour < 14 and not result.empty:

    # Create Bar (Avg Installs)
    fig = px.bar(
        result,
        x=result.index,
        y="Installs",
        labels={"x": "App Type (Free vs Paid)", "Installs": "Average Installs"},
        title="Dual Axis Chart: Avg Installs vs Revenue (Top 3 Categories)"
    )

    # Add Line (Avg Revenue)
    fig.add_scatter(
        x=result.index,
        y=result["Revenue"],
        mode="lines+markers",
        name="Average Revenue",
        yaxis="y2"
    )

    # Add secondary y-axis
    fig.update_layout(
        yaxis2=dict(
            title="Average Revenue",
            overlaying="y",
            side="right"
        )
    )

    fig.show()
    import plotly.io as pio
    pio.write_html(fig, "task_2.html", auto_open=False)

else:
    print("Graph visible only between 1 PM IST and 2 PM IST.")
# Out:
# Graph visible only between 1 PM IST and 2 PM IST.
